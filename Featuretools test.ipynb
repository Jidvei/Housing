# %%
#https://www.kaggle.com/willkoehrsen/automated-feature-engineering-basics
# pandas and numpy for data manipulation
import pandas as pd
import numpy as np

# featuretools for automated feature engineering
import featuretools as ft

# matplotlit and seaborn for visualizations
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 22
import seaborn as sns

# Suppress warnings from pandas
import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ...   PoolQC Fence MiscFeature MiscVal MoSold YrSold  \
# 0         Lvl    AllPub  ...      NaN   NaN         NaN       0      2   2008
# 1         Lvl    AllPub  ...      NaN   NaN         NaN       0      5   2007
# 2         Lvl    AllPub  ...      NaN   NaN         NaN       0      9   2008
# 3         Lvl    AllPub  ...      NaN   NaN         NaN       0      2   2006
# 4         Lvl    AllPub  ...      NaN   NaN         NaN       0     12   2008
#
#   SaleType  SaleCondition  SalePrice    set
# 0       WD         Normal     208500  train
# 1       WD         Normal     181500  train
# 2       WD         Normal     223500  train
# 3       WD        Abnorml     140000  train
# 4       WD         Normal     250000  train
#
# [5 rows x 82 columns]

# %%
#Tilføjer en kolonne ti lat separare træningsset og testset.
#Laver target variable og indsætter NAN i testsæt
train['set'] = 'train'
test['set'] = 'test'
test["SalePrice"] = np.nan

# %%
app = train.append(test, ignore_index = True)

# %%
es = ft.EntitySet(id = 'Id')

# %%
es = es.entity_from_dataframe(entity_id = 'app', dataframe = app, index = 'Id')

# %%
# List the primitives in a dataframe
primitives = ft.list_primitives()
pd.options.display.max_colwidth = 100
primitives[primitives['type'] == 'aggregation'].head(10)
# Out:
#                name         type  \
# 0   time_since_last  aggregation
# 1               sum  aggregation
# 2  avg_time_between  aggregation
# 3               all  aggregation
# 4             count  aggregation
# 5              last  aggregation
# 6          num_true  aggregation
# 7             trend  aggregation
# 8               any  aggregation
# 9               max  aggregation
#
#                                                       description
# 0                               Time since last related instance.
# 1  Counts the number of elements of a numeric or boolean feature.
# 2           Computes the average time between consecutive events.
# 3                                  Test if all values are 'True'.
# 4                           Counts the number of non null values.
# 5                                         Returns the last value.
# 6                 Finds the number of 'True' values in a boolean.
# 7  Calculates the slope of the linear trend of variable overtime.
# 8                                    Test if any value is 'True'.
# 9          Finds the maximum non-null value of a numeric feature.

# %%
primitives[primitives['type'] == 'transform'].head(10)
# Out:
#           name       type  \
# 19         not  transform
# 20    numwords  transform
# 21         and  transform
# 22        year  transform
# 23       month  transform
# 24        days  transform
# 25     cum_min  transform
# 26     minutes  transform
# 27     weekend  transform
# 28  percentile  transform
#
#                                                                                         description
# 19                                   For each value of the base feature, negates the boolean value.
# 20                                      Returns the words in a given string by counting the spaces.
# 21                                     For two boolean values, determine if both values are 'True'.
# 22                                                      Transform a Datetime feature into the year.
# 23                                                     Transform a Datetime feature into the month.
# 24                                           Transform a Timedelta feature into the number of days.
# 25  Calculates the min of previous values of an instance for each value in a time-dependent entity.
# 26                                        Transform a Timedelta feature into the number of minutes.
# 27                                          Transform Datetime feature into the boolean of Weekend.
# 28                        For each value of the base feature, determines the percentile in relation

# %%
default_agg_primitives =  ["sum", "std", "max", "skew", "min", "mean", "count", "percent_true", "num_unique", "mode"]
default_trans_primitives =  ["day", "year", "month", "weekday", "haversine", "numwords", "characters"]

# DFS with specified primitives
feature_matrix, feature_names = ft.dfs(entityset = es, target_entity = 'app',
                                       trans_primitives = default_trans_primitives,
                                       agg_primitives=default_agg_primitives, 
                                        max_depth = 3, features_only=False, verbose = True)

print('%d Total Features' % len(feature_names))
# Out:
# Built 81 features
# Elapsed: 00:00 | Remaining: 00:00 | Progress: 100%|██████████████████████████████████████████| Calculated: 11/11 chunks
# 81 Total Features

# %%
feature_matrix.head()
# Out:
#     1stFlrSF  2ndFlrSF  3SsnPorch Alley  BedroomAbvGr BldgType BsmtCond  \
# Id
# 1        856       854          0   NaN             3     1Fam       TA
# 2       1262         0          0   NaN             3     1Fam       TA
# 3        920       866          0   NaN             3     1Fam       TA
# 4        961       756          0   NaN             3     1Fam       Gd
# 5       1145      1053          0   NaN             4     1Fam       TA
#
#    BsmtExposure  BsmtFinSF1  BsmtFinSF2  ...   ScreenPorch Street  \
# Id                                       ...
# 1            No       706.0         0.0  ...             0   Pave
# 2            Gd       978.0         0.0  ...             0   Pave
# 3            Mn       486.0         0.0  ...             0   Pave
# 4            No       216.0         0.0  ...             0   Pave
# 5            Av       655.0         0.0  ...             0   Pave
#
#     TotRmsAbvGrd  TotalBsmtSF Utilities  WoodDeckSF YearBuilt YearRemodAdd  \
# Id
# 1              8        856.0    AllPub           0      2003         2003
# 2              6       1262.0    AllPub         298      1976         1976
# 3              6        920.0    AllPub           0      2001         2002
# 4              7        756.0    AllPub           0      1915         1970
# 5              9       1145.0    AllPub         192      2000         2000
#
#    YrSold    set
# Id
# 1    2008  train
# 2    2007  train
# 3    2008  train
# 4    2006  train
# 5    2008  train
#
# [5 rows x 81 columns]

# %%
feature_matrix_spec, feature_names_spec = ft.dfs(entityset = es, target_entity = 'app',  
                                                 agg_primitives = ['sum', 'count', 'min', 'max', 'mean', 'mode'], 
                                                 max_depth = 2, features_only = False, verbose = True)
# Out:
# Built 81 features
# Elapsed: 00:00 | Remaining: 00:00 | Progress: 100%|██████████████████████████████████████████| Calculated: 11/11 chunks
